# %%
import datasets
import torch

# %%
dataset = datasets.load_dataset(
    "draco976/wikipedia-bookcorpus",
    split="train"
)
# Out:
# ...
# Loading dataset shards:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
import random

# %%
dataset['text'][random.choice([i for i in range(1000)])]
# Out:
# ['of',
#  'India',
#  'in',
#  '1947',
#  ',',
#  'Gayatri',
#  'Devi',
#  'ran',
#  'for',
#  'Parliament',
#  'in',
#  '1962',
#  'and',
#  'won',
#  'the',
#  'constituency',
#  'in',
#  'the',
#  'Lok',
#  'Sabha',
#  'in',
#  'the',
#  'world',
#  "'s",
#  'largest',
#  'landslide',
#  ',',
#  'winning',
#  '192,909',
#  'votes',
#  'out',
#  'of',
#  '246,516',
#  'cast',
#  '.',
#  'She',
#  'continued',
#  'to',
#  'hold',
#  'this',
#  'seat',
#  'on',
#  '1967',
#  'and',
#  '1971',
#  'as',
#  'a',
#  'member',
#  'of',
#  'the',
#  'Swatantra',
#  'Party',
#  'founded',
#  'by',
#  'C.',
#  'Rajagopalachari',
#  ',',
#  'running',
#  'against',
#  'the',
#  'Indian',
#  'National',
#  'Congress',
#  'party',
#  '.',
#  '\n\n',
#  'In',
#  '1965',
#  ',',
#  'during',
#  'a',
#  'meeting',
#  'with',
#  'Prime',
#  'Minister',
#  'Lal',
#  'Bahadur',
#  'Shastri',
#  ',',
#  'Gayatri',
#  'was',
#  'again',
#  'asked',
#  'to',
#  'join',
#  'Congress',
#  '.',
#  'This',
# ...

# %%
from training.dataloader import get_data

# %%
data = get_data()
# Out:
# ...
# Resolving data files:   0%|          | 0/80 [00:00<?, ?it/s]

# %%
from src.tokenizer import Tokenizer
tkn = Tokenizer()

# %%
i = 0
for o in data:
    x, y = o
    print(len(x[0]==512))
    i = i+1
    if i>10:
        break
# Out:
# 512
# 512
# 512
# 512
# 512
# 512
# 512
# 512
# 512
# 512
# 512
