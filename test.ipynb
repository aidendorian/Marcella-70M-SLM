# %%
import datasets
import torch

# %%
dataset = datasets.load_dataset(
    "shahrukhx01/wikipedia-bookscorpus-en-preprocessed",
    split="train"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
import random

# %%
dataset['text'][random.choice([i for i in range(1000)])]
# Out:
# 'during a couple of lowkey events in denmark the group performed live versions of songs intended for inclusion on the third album including couch potato and shakin stevens is a superstar the latter a tribute to the 1980s performer shakin stevens the songs were said to have incorporated a rock sound into their music\n\nin december 2000 mattel filed a lawsuit against the groups record label mattel v mca records 296 f3d 894 9th cir 2002 claiming that barbie girl had damaged the reputation of the barbie brand judge alex kozinski writing for the united states court of appeals for the ninth circuit upheld the district court finding the use of mattels trademark in barbie girl fell within the noncommercial use exemption to the federal trademark dilution act'
